# %%
import sys
# !{sys.executable} -m pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org opencv-python pandas numpy matplotlib scikit-learn tqdm
# Out:
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import pandas as pd
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

print("Library berhasil diimport!")
# Out:
# Library berhasil diimport!

# %%
# Konfigurasi path
DATA_DIR = "data"
IMAGE_DIR = os.path.join(DATA_DIR, "HAM10000_images")
METADATA_PATH = os.path.join(DATA_DIR, "HAM10000_metadata.csv")
TARGET_SIZE = (128, 128)  # Bisa ganti ke (64,64) atau (224,224) sesuai kebutuhan
RANDOM_SEED = 42

# Mapping label
LABEL_MAPPING = {
    'akiec': 0,  # Actinic Keratosis
    'bcc': 1,    # Basal Cell Carcinoma
    'bkl': 2,    # Benign Keratosis
    'df': 3,     # Dermatofibroma
    'mel': 4,    # Melanoma
    'nv': 5,     # Nevus (tahi lalat)
    'vasc': 6    # Vascular Lesion
}

print(f"Folder data: {DATA_DIR}")
print(f"Folder gambar: {IMAGE_DIR}")
print(f"Target resize: {TARGET_SIZE}")
# Out:
# Folder data: data
# Folder gambar: data\HAM10000_images
# Target resize: (128, 128)
